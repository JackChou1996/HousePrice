# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import KFold
# from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Lasso
from scipy import stats
from scipy.stats import norm, skew  # for some statistics
# 选择模型参数
from sklearn.model_selection import GridSearchCV
# KNNR参数选择
from sklearn.neighbors import KNeighborsRegressor
# RandomForest参数选择
from sklearn.ensemble import RandomForestRegressor
# 设定默认字体
from pylab import mpl
# 导入自定义工具

import Utils.utils as utils
#mpl.rcParams['font.sans-serif'] = ['SimHei']

path = './datasets/house-price/'

bj_house = utils.load_data(path, file_name='bj_house.csv')
# sh_house = utils.load_data(path, file_name='shanghai_7w.xlsx', is_csv=False)

# 查看数据集信息
na_data = utils.nan_data_rate(bj_house, 5)
num_lst, class_lst = utils.describle_data(bj_house)
print("缺失率", na_data)
print(num_lst, class_lst)
# Out:
# 数据集 bj_house.csv 加载成功
# 变量名为: ['id', 'Lng', 'Lat', 'Cid', 'tradeTime', 'DOM', 'followers', 'totalPrice', 'price', 'square', 'livingRoom', 'drawingRoom', 'kitchen', 'bathRoom', 'floor', 'buildingType', 'constructionTime', 'renovationCondition', 'buildingStructure', 'ladderRatio', 'elevator', 'fiveYearsProperty', 'subway', 'district', 'communityAverage', 'period', 'sta_square', 'sta_price', 'avg_price', 'avg_community', 'trade_year']
# 缺失率                   Missing_Ratio
# DOM                   49.545713
# period                46.061326
# buildingType           0.633838
# avg_community          0.145209
# communityAverage       0.145209
#                                均值           中位数  \
# 变量
# Lng                  1.164185e+02  1.164168e+02
# Lat                  3.994959e+01  3.993453e+01
# Cid                  1.128066e+12  1.110000e+12
# DOM                  2.882234e+01  6.000000e+00
# followers            1.673151e+01  5.000000e+00
# totalPrice           3.490302e+02  2.940000e+02
# price                4.353044e+04  3.873700e+04
# square               8.324060e+01  7.426000e+01
# drawingRoom          1.171950e+00  1.000000e+00
# kitchen              9.943385e-01  1.000000e+00
# bathRoom             1.188122e+00  1.000000e+00
# buildingType         3.010116e+00  4.000000e+00
# renovationCondition  2.606573e+00  3.000000e+00
# ladderRatio          6.316491e+01  3.330000e-01
# elevator             5.770156e-01  1.000000e+00
# fiveYearsProperty    6.455492e-01  1.000000e+00
# subway               6.010519e-01  1.000000e+00
# district             6.763564e+00  7.000000e+00
# communityAverage     6.368245e+04  5.901500e+04
# sta_square           4.390924e-02  3.874382e-02
# sta_price            2.785902e-01  2.479120e-01
# avg_price            4.352998e+00  3.873614e+00
# avg_community        3.067156e-01  2.796206e-01
# trade_year           2.014784e+03  2.015000e+03
#
#                                                    众数           标准差  \
# 变量
# Lng                    0    116.343245
# dtype: float64  1.120543e-01
# Lat                     0    39.900529
# dtype: float64  9.198255e-02
# Cid                  0    1.110000e+12
# dtype: float64  2.356416e+12
# DOM                           0    1.0
# dtype: float64  5.023734e+01
# followers                         0    0
# dtype: int64  3.420918e+01
# totalPrice                  0    300.0
# dtype: float64  2.307808e+02
# price                         0    50000
# dtype: int64  2.170902e+04
# square                       0    89.0
# dtype: float64  3.723466e+01
# drawingRoom                   0    1.0
# dtype: float64  5.222875e-01
# kitchen                       0    1.0
# dtype: float64  1.061854e-01
# bathRoom                      0    1.0
# dtype: float64  4.375438e-01
# buildingType                  0    4.0
# dtype: float64  1.269616e+00
# renovationCondition           0    1.0
# dtype: float64  1.311575e+00
# ladderRatio                   0    0.5
# dtype: float64  2.506851e+04
# elevator                          0    1
# dtype: int64  4.940338e-01
# fiveYearsProperty                 0    1
# dtype: int64  4.783473e-01
# subway                            0    1
# dtype: int64  4.896828e-01
# district                          0    7
# dtype: int64  2.812616e+00
# communityAverage          0    92360.0
# dtype: float64  2.232922e+04
# sta_square               0    0.047222
# dtype: float64  2.141646e-02
# sta_price                0    0.319996
# dtype: float64  1.389386e-01
# avg_price                     0    5.0
# dtype: float64  2.170899e+00
# avg_community            0    0.473192
# dtype: float64  1.296236e-01
# trade_year                     0    2016
# dtype: int64  1.656591e+00
#
#                              四分位差            极差
# 变量
# Lng                      0.132596  6.598640e-01
# Lat                      0.109818  6.257280e-01
# Cid                      0.000000  1.108890e+15
# DOM                     36.000000  1.676000e+03
# followers               18.000000  1.143000e+03
# totalPrice             220.500000  1.812990e+04
# price                25769.500000  1.562490e+05
# square                  40.810000  1.738600e+03
# drawingRoom              0.000000  5.000000e+00
# kitchen                  0.000000  4.000000e+00
# bathRoom                 0.000000  7.000000e+00
# buildingType             3.000000  3.000000e+00
# renovationCondition      3.000000  3.000000e+00
# ladderRatio              0.250000  1.000940e+07
# elevator                 1.000000  1.000000e+00
# fiveYearsProperty        1.000000  1.000000e+00
# subway                   1.000000  1.000000e+00
# district                 2.000000  1.200000e+01
# communityAverage     29611.000000  1.722620e+05
# sta_square               0.023473  1.000000e+00
# sta_price                0.164926  1.000000e+00
# avg_price                2.576962  1.562453e+01
# avg_community            0.171895  1.000000e+00
# trade_year               3.000000  1.600000e+01   [1.01E+11        92216
# BJCY87525657        1
# BJXC84882327        1
# BJSY87525726        1
# BJCY90705405        1
#                 ...
# BJCP88896045        1
# BJDX88874418        1
# BJHD91055831        1
# BJSJ87151611        1
# BJDC91531962        1
# Name: id, Length: 226636, dtype: int64, 2016/2/28     1096
# 2016/3/6       948
# 2016/7/31      940
# 2016/8/31      910
# 2016/3/5       824
#               ...
# 2011/3/21        1
# 2012/1/28        1
# 2010/2/26        1
# 2010/12/25       1
# 2010/1/5         1
# Name: tradeTime, Length: 2560, dtype: int64, 2         160589
# 1          82386
# 3          67611
# 4           6821
# 5           1107
# 6            228
# 7             37
# #NAME?        32
# 0             28
# 8              7
# 9              5
# Name: livingRoom, dtype: int64, 中 6     34794
# 顶 6     22765
# 高 6     20905
# 低 6     15744
# 底 6     13338
#         ...
# 低 36        2
# 低 35        1
# 低 63        1
# 低 2         1
# 低 5         1
# Name: floor, Length: 201, dtype: int64, 2004    21149
# 2003    19416
# 未知      19285
# 2005    18926
# 2006    14863
#         ...
# 1934        2
# 1944        2
# 1906        1
# 1914        1
# 1933        1
# Name: constructionTime, Length: 72, dtype: int64, 6       188067
# 2       115779
# 4        14341
# 3          253
# 1          192
# 5          187
# 钢混结构        17
# 混合结构        15
# Name: buildingStructure, dtype: int64, 2000-2004    77412
# 2005-2008    60153
# 2009-2012    29385
# 2013-2016     5034
# Name: period, dtype: int64]

# %%
sum(bj_house['livingRoom']=='#NAME?')
# Out:
# 32

# %%
bj_house['livingRoom'].unique()
# Out:
# array(['2', '3', '1', '4', '5', '6', '9', '0', '7', '8', '#NAME?'],
#       dtype=object)

# %%
import pandas as pd
# 缺失值填补
# 房屋的厨房数，卫生间数。客厅数等都与住房面积高度相关
squ_bins = [-1,20,50,90,120,160,200,2000]
bj_house['squ_level'] = pd.cut(bj_house['square'],bins=squ_bins,labels = ['20平以下','20-50','50-90','90-120','120-160','160-200','200平以上'])
bj_house.loc[bj_house['livingRoom']=='#NAME?','livingRoom'] = None

# %%
bj_house['livingRoom'] = bj_house.groupby('squ_level')['livingRoom'].transform(lambda x:x.fillna(x.median()))
bj_house['livingRoom'] = bj_house['livingRoom'].map(lambda x: int(x))
bj_house['livingRoom'].unique()
# Out:
# array([2, 3, 1, 4, 5, 6, 9, 0, 7, 8])

# %%
bj_house['drawingRoom'] = bj_house.groupby('squ_level')['drawingRoom'].transform(lambda x:x.fillna(x.median()))
bj_house['drawingRoom'] = bj_house['drawingRoom'].map(lambda x: int(x))
sum(bj_house['drawingRoom'].isnull())
# Out:
# 0

# %%
bj_house['kitchen'] = bj_house.groupby('squ_level')['kitchen'].transform(lambda x:x.fillna(x.median()))
bj_house['kitchen'] = bj_house['kitchen'].map(lambda x: int(x))
sum(bj_house['kitchen'].isnull())
# Out:
# 0

# %%
bj_house['bathRoom'] = bj_house.groupby('squ_level')['bathRoom'].transform(lambda x:x.fillna(x.median()))
bj_house['bathRoom'] = bj_house['bathRoom'].map(lambda x: int(x))
sum(bj_house['bathRoom'].isnull())
# Out:
# 0

# %%
bj_house['num_room'] = bj_house['livingRoom'].map(lambda x:int(x))+bj_house['drawingRoom'].map(lambda x:int(x))+bj_house['kitchen'].map(lambda x:int(x))+bj_house['bathRoom'].map(lambda x:int(x))
bj_house['living_rate'] = bj_house['livingRoom'].map(lambda x:int(x)) / bj_house['num_room']

# %%
bj_house['buildingType'] = bj_house['buildingType'].fillna('无类型')
bj_house.loc[bj_house['buildingType'] == 1,'buildingType'] = '塔楼'
bj_house.loc[bj_house['buildingType'] == 2,'buildingType'] = '平房'
bj_house.loc[bj_house['buildingType'] == 3,'buildingType'] = '板塔结合'
bj_house.loc[bj_house['buildingType'] == 4,'buildingType'] = '板楼'
bj_house['buildingType'].unique()
# Out:
# array(['塔楼', '板楼', '板塔结合', '无类型', '平房'], dtype=object)

# %%
# 缺失值填补
bj_house['renovationCondition'] = bj_house['renovationCondition'].fillna('其他')
bj_house.loc[bj_house['renovationCondition'] == 1,'renovationCondition'] = '其他'
bj_house.loc[bj_house['renovationCondition'] == 2,'renovationCondition'] = '毛坯'
bj_house.loc[bj_house['renovationCondition'] == 3,'renovationCondition'] = '简装'
bj_house.loc[bj_house['renovationCondition'] == 4,'renovationCondition'] = '精装'

sum(bj_house['renovationCondition'].isnull())
# Out:
# 0

# %%
bj_house.loc[bj_house['district']==1,'district'] = '东城'
bj_house.loc[bj_house['district']==2,'district'] = '丰台'
bj_house.loc[bj_house['district']==3,'district'] = '亦庄'
bj_house.loc[bj_house['district']==4,'district'] = '大兴'
bj_house.loc[bj_house['district']==5,'district'] = '房山'
bj_house.loc[bj_house['district']==6,'district'] = '昌平'
bj_house.loc[bj_house['district']==7,'district'] = '朝阳'
bj_house.loc[bj_house['district']==8,'district'] = '海淀'
bj_house.loc[bj_house['district']==9,'district'] = '石景山'
bj_house.loc[bj_house['district']==10,'district'] = '西城'
bj_house.loc[bj_house['district']==11,'district'] = '通州'
bj_house.loc[bj_house['district']==12,'district'] = '门头沟'
bj_house.loc[bj_house['district']==13,'district'] = '顺义'
bj_house['district'].unique()
# Out:
# array(['朝阳', '昌平', '东城', '顺义', '西城', '丰台', '海淀', '大兴', '房山', '亦庄', '石景山',
#        '门头沟', '通州'], dtype=object)

# %%
bj_house['renovationCondition'].unique()
# Out:
# array(['砖木结构', '砖混结构', '未知结构', '混合结构', '其他'], dtype=object)

# %%
bj_house.loc[bj_house['buildingStructure']=='1','buildingStructure'] = '未知结构'
bj_house.loc[bj_house['buildingStructure']=='2','buildingStructure'] = '混和结构'
bj_house.loc[bj_house['buildingStructure']=='3','buildingStructure'] = '砖木结构'
bj_house.loc[bj_house['buildingStructure']=='4','buildingStructure'] = '砖混结构'
bj_house.loc[bj_house['buildingStructure']=='5','buildingStructure'] = '钢结构'
bj_house.loc[bj_house['buildingStructure']=='6','buildingStructure'] = '钢混结构'

# %%
# 统计各个区的房价中位数
def get_median(data,val,tar):
    return data.groupby(val)[tar].median()

# %%
dis_price_median = get_median(bj_house,'district','price')
dis_price_median.values
# Out:
# array([56769.5, 35543. , 29060. , 26897. , 26833. , 27237.5, 40146.5,
#        50810. , 32179. , 62582. , 23440.5, 23346.5, 21623.5])

# %%
from pyecharts import options as opts
from pyecharts.charts import Map, Page, Timeline, Grid
from pyecharts.charts import Geo, Bar, Line, Gauge, Pie
from pyecharts.globals import ChartType, SymbolType
from pyecharts.globals import ThemeType

# %%
dis = [list(z) for z in zip(dis_price_median.index, dis_price_median.values)]
dis[2][0] = '大兴'
dis
# Out:
# [['东城', 56769.5],
#  ['丰台', 35543.0],
#  ['大兴', 29060.0],
#  ['大兴', 26897.0],
#  ['房山', 26833.0],
#  ['昌平', 27237.5],
#  ['朝阳', 40146.5],
#  ['海淀', 50810.0],
#  ['石景山', 32179.0],
#  ['西城', 62582.0],
#  ['通州', 23440.5],
#  ['门头沟', 23346.5],
#  ['顺义', 21623.5]]

# %%
#热力地图
def geo_heatmap() -> Geo:
    c = (
        Geo()
        .add_schema(maptype="北京")
        .add(
            "房屋均价",
            dis,
            #[list(z) for z in zip(dis_price_median.index, dis_price_median.values)],
            type_=ChartType.HEATMAP,
        )
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(title_opts=opts.TitleOpts(title="Map-广东地图"), visualmap_opts=opts.VisualMapOpts())
    )   
    return c
geo_heatmap().render_notebook()
# Out:
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '北京':'https://assets.pyecharts.org/assets/maps/beijing'
#         }
#     });
# </script>
#
#         <div id="10cb15e8d7f2425e973ee3c934cdd40f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '北京'], function(echarts) {
#                 var chart_10cb15e8d7f2425e973ee3c934cdd40f = echarts.init(
#                     document.getElementById('10cb15e8d7f2425e973ee3c934cdd40f'), 'white', {renderer: 'canvas'});
#                 var option_10cb15e8d7f2425e973ee3c934cdd40f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u623f\u5c4b\u5747\u4ef7",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u4e1c\u57ce",
#                     "value": [
#                         116.42,
#                         39.93,
#                         56769.5
#                     ]
#                 },
#                 {
#                     "name": "\u4e30\u53f0",
#                     "value": [
#                         116.28,
#                         39.85,
#                         35543.0
#                     ]
#                 },
#                 {
#                     "name": "\u5927\u5174",
#                     "value": [
#                         116.33,
#                         39.73,
#                         29060.0
#                     ]
#                 },
#                 {
#                     "name": "\u5927\u5174",
#                     "value": [
#                         116.33,
#                         39.73,
#                         26897.0
#                     ]
#                 },
#                 {
#                     "name": "\u623f\u5c71",
#                     "value": [
#                         116.13,
#                         39.75,
#                         26833.0
#                     ]
#                 },
#                 {
#                     "name": "\u660c\u5e73",
#                     "value": [
#                         116.23,
#                         40.22,
#                         27237.5
#                     ]
#                 },
#                 {
#                     "name": "\u671d\u9633",
#                     "value": [
#                         120.27,
#                         41.34,
#                         40146.5
#                     ]
#                 },
#                 {
#                     "name": "\u6d77\u6dc0",
#                     "value": [
#                         116.3,
#                         39.95,
#                         50810.0
#                     ]
#                 },
#                 {
#                     "name": "\u77f3\u666f\u5c71",
#                     "value": [
#                         116.22,
#                         39.9,
#                         32179.0
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u57ce",
#                     "value": [
#                         116.37,
#                         39.92,
#                         62582.0
#                     ]
#                 },
#                 {
#                     "name": "\u901a\u5dde",
#                     "value": [
#                         121.03,
#                         32.05,
#                         23440.5
#                     ]
#                 },
#                 {
#                     "name": "\u95e8\u5934\u6c9f",
#                     "value": [
#                         116.1,
#                         39.93,
#                         23346.5
#                     ]
#                 },
#                 {
#                     "name": "\u987a\u4e49",
#                     "value": [
#                         116.65,
#                         40.13,
#                         21623.5
#                     ]
#                 }
#             ],
#             "pointSize": 20,
#             "blurSize": 20,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u623f\u5c4b\u5747\u4ef7"
#             ],
#             "selected": {
#                 "\u623f\u5c4b\u5747\u4ef7": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Map-\u5e7f\u4e1c\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "\u5317\u4eac",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_10cb15e8d7f2425e973ee3c934cdd40f.setOption(option_10cb15e8d7f2425e973ee3c934cdd40f);
#         });
#     </script>

# %%
bj_house['buildingStructure'].unique()
# Out:
# array(['6', '2', '4', '1', '5', '3', '混合结构', '钢混结构'], dtype=object)

# %%
bj_house['constructionTime'].unique()
sum(bj_house['period'].isnull())
# Out:
# 146867

# %%
# 绘制缺失率直方图
utils.show_bar(na_data.index, na_data['Missing_Ratio'], "Rate of Missing Value")

# %%
bj_house.head()
# Out:
#             id         Lng        Lat           Cid   tradeTime     DOM  \
# 0  1.01085E+11  116.475489  40.019520  1.111030e+12    2016/8/9  1464.0
# 1  1.01086E+11  116.453917  39.881534  1.111030e+12   2016/7/28   903.0
# 2  1.01086E+11  116.561978  39.877145  1.111040e+12  2016/12/11  1271.0
# 3  1.01086E+11  116.438010  40.076114  1.111040e+12   2016/9/30   965.0
# 4  1.01087E+11  116.428392  39.886229  1.111030e+12   2016/8/28   927.0
#
#    followers  totalPrice  price  square  ... buildingType constructionTime  \
# 0        106       415.0  31680  131.00  ...          1.0             2005
# 1        126       575.0  43436  132.38  ...          1.0             2004
# 2         48      1030.0  52021  198.00  ...          4.0             2005
# 3        138       297.5  22202  134.00  ...          1.0             2008
# 4        286       392.0  48396   81.00  ...          4.0             1960
#
#    renovationCondition buildingStructure ladderRatio  elevator  \
# 0                    3                 6       0.217       1.0
# 1                    4                 6       0.667       1.0
# 2                    3                 6       0.500       1.0
# 3                    1                 6       0.273       1.0
# 4                    2                 2       0.333       0.0
#
#   fiveYearsProperty  subway  district  communityAverage
# 0               0.0     1.0         7           56021.0
# 1               1.0     0.0         7           71539.0
# 2               0.0     0.0         7           48160.0
# 3               0.0     0.0         6           51238.0
# 4               1.0     1.0         1           62588.0
#
# [5 rows x 25 columns]

# %%
bj_house['constructionTime'].value_counts()
# Out:
# 2004    21149
# 2003    19416
# 未知      19285
# 2005    18926
# 2006    14863
#         ...
# 1934        2
# 1944        2
# 1906        1
# 1914        1
# 1933        1
# Name: constructionTime, Length: 72, dtype: int64

# %%
bj_house.loc[bj_house['constructionTime']>='2000','constructionTime'].value_counts()
# Out:
# 2004    21149
# 2003    19416
# 未知      19285
# 2005    18926
# 2006    14863
# 2007    14213
# 2000    13906
# 2002    12358
# 2008    12162
# 2009    11565
# 2001    10597
# 2010     7243
# 2011     5521
# 2012     5057
# 2013     2344
# 2014     2127
# 2015      478
# 2016       85
# Name: constructionTime, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import mpl
#mpl.rcParams['font.sans-serif'] = ['SimHei']

# %%
# 我们只研究2000年-2016年的房价信息
time_bins = ['1999','2004','2008','2012','2017']
bj_house['period'] = pd.cut(bj_house['constructionTime'], bins = time_bins,labels = ['2000-2004','2005-2008','2009-2012','2013-2016'])
bj_house['period'].value_counts()
# Out:
# 2000-2004    77426
# 2005-2008    60164
# 2009-2012    29386
# 2013-2016     5034
# Name: period, dtype: int64

# %%
def get_time_median(data,val,tar):
    time = ['%s'%i for i in range(2000,2017)]
    print(time)
    dic = {}
    for _ in time:
        # 提取指定年份数据
        temp = bj_house[bj_house['constructionTime']==_]
        temp = temp.loc[temp[val]!='亦庄']
        print(temp['constructionTime'].unique())
        # 调用函数获取分组信息
        res = get_median(temp,val,tar)
        print(res)
        dic[_] = [list(z) for z in zip(res.index,res.values)]
    return dic

# %%
time_price = get_time_median(bj_house,'district','price')
# Out:
# ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']
# ['2000']
# district
# 东城     54033.0
# 丰台     33953.0
# 大兴     22504.0
# 房山     18160.0
# 昌平     26807.5
# 朝阳     37480.5
# 海淀     42845.0
# 石景山    30195.0
# 西城     58249.5
# 通州     20956.0
# 门头沟    21411.5
# 顺义     19567.5
# Name: price, dtype: float64
# ['2001']
# district
# 东城     47893.0
# 丰台     34645.0
# 大兴     24954.5
# 房山     18057.5
# 昌平     22498.0
# 朝阳     37478.5
# 海淀     47691.5
# 石景山    30509.0
# 西城     50814.0
# 通州     23333.0
# 门头沟    21989.0
# 顺义     19661.0
# Name: price, dtype: float64
# ['2002']
# district
# 东城     55951.0
# 丰台     34182.0
# 大兴     24418.5
# 房山     21361.5
# 昌平     26332.5
# 朝阳     39793.5
# 海淀     44919.0
# 石景山    30592.0
# 西城     52447.0
# 通州     22666.5
# 门头沟    23931.0
# 顺义     19452.0
# Name: price, dtype: float64
# ['2003']
# district
# 东城     63694.0
# 丰台     33183.0
# 大兴     26833.5
# 房山     19787.5
# 昌平     25096.0
# 朝阳     37098.0
# 海淀     47251.0
# 石景山    31222.5
# 西城     60714.0
# 通州     21686.0
# 门头沟    23049.5
# 顺义     19815.0
# Name: price, dtype: float64
# ['2004']
# district
# 东城     55249.0
# 丰台     34612.0
# 大兴     25554.5
# 房山     23586.5
# 昌平     27430.0
# 朝阳     38913.0
# 海淀     50172.0
# 石景山    36752.0
# 西城     53265.0
# 通州     23511.0
# 门头沟    22837.0
# 顺义     22157.0
# Name: price, dtype: float64
# ['2005']
# district
# 东城     52243.5
# 丰台     36967.0
# 大兴     28019.5
# 房山     22000.0
# 昌平     26356.0
# 朝阳     38985.5
# 海淀     47263.0
# 石景山    41910.5
# 西城     57046.0
# 通州     24052.5
# 门头沟    22137.5
# 顺义     22649.0
# Name: price, dtype: float64
# ['2006']
# district
# 东城     54546.0
# 丰台     36601.5
# 大兴     25790.0
# 房山     22151.5
# 昌平     30445.0
# 朝阳     40280.0
# 海淀     47872.0
# 石景山    41682.0
# 西城     50998.0
# 通州     24744.0
# 门头沟    23274.0
# 顺义     25069.5
# Name: price, dtype: float64
# ['2007']
# district
# 东城     55952.0
# 丰台     35624.0
# 大兴     27327.5
# 房山     21929.5
# 昌平     28604.0
# 朝阳     37872.5
# 海淀     48822.5
# 石景山    40026.0
# 西城     64227.0
# 通州     22651.0
# 顺义     24313.0
# Name: price, dtype: float64
# ['2008']
# district
# 东城     60948.5
# 丰台     39774.5
# 大兴     26855.0
# 房山     21485.0
# 昌平     26467.0
# 朝阳     41692.0
# 海淀     44204.0
# 石景山    42937.0
# 西城     69691.0
# 通州     27967.0
# 门头沟    25303.5
# 顺义     23699.5
# Name: price, dtype: float64
# ['2009']
# district
# 东城     44087.0
# 丰台     35254.0
# 大兴     30468.5
# 房山     22393.0
# 昌平     29188.0
# 朝阳     39809.0
# 海淀     43036.0
# 石景山    36608.0
# 西城     63762.5
# 通州     27847.0
# 顺义     20988.0
# Name: price, dtype: float64
# ['2010']
# district
# 东城     65416
# 丰台     36317
# 大兴     30751
# 房山     26761
# 昌平     36808
# 朝阳     45905
# 海淀     40686
# 石景山    37895
# 西城     46764
# 通州     21603
# 顺义     23069
# Name: price, dtype: int64
# ['2011']
# district
# 东城     62237.0
# 丰台     49352.5
# 大兴     34144.5
# 房山     25913.0
# 昌平     29338.0
# 朝阳     41830.0
# 海淀     47282.0
# 石景山    45164.0
# 西城     67278.5
# 通州     27954.0
# 门头沟    17137.0
# 顺义     24887.0
# Name: price, dtype: float64
# ['2012']
# district
# 东城     67618
# 丰台     43618
# 大兴     38270
# 房山     31326
# 昌平     36381
# 朝阳     50808
# 海淀     44986
# 石景山    50766
# 西城     57453
# 通州     40030
# 门头沟    39228
# 顺义     23546
# Name: price, dtype: int64
# ['2013']
# district
# 东城     56878.0
# 丰台     45778.5
# 大兴     44160.0
# 房山     26580.0
# 昌平     37728.5
# 朝阳     58920.5
# 海淀     53764.0
# 西城     80720.0
# 通州     43063.5
# 门头沟    45335.0
# 顺义     29872.0
# Name: price, dtype: float64
# ['2014']
# district
# 丰台    46920.5
# 大兴    37171.0
# 房山    34190.0
# 昌平    45109.0
# 朝阳    54948.0
# 海淀    68677.0
# 西城    37034.0
# 通州    38048.5
# 顺义    21819.0
# Name: price, dtype: float64
# ['2015']
# district
# 丰台    47873.0
# 大兴    47669.0
# 房山    32790.0
# 昌平    49067.0
# 朝阳    58095.0
# 海淀    51223.0
# 通州    38337.0
# 顺义    34478.5
# Name: price, dtype: float64
# ['2016']
# district
# 大兴     31773
# 房山     40000
# 昌平     54497
# 朝阳     90190
# 海淀    102588
# 西城    132417
# Name: price, dtype: int64

# %%
sum(bj_house['constructionTime']=='2000')
# Out:
# 13906

# %%
#时间轴轮播热力图
#这里两幅图所用数据差异不大,所以看不太出来区别
def timeline_map() -> Timeline:
    tl = Timeline()
    for price in time_price:
        geo_ = (
            Geo(init_opts = opts.InitOpts(width = 1200,height = 800)
               )
        .add_schema(maptype="北京")
        .add(
            "房屋均价",
            time_price[price],
            #[list(z) for z in zip(dis_price_median.index, dis_price_median.values)],
            type_=ChartType.HEATMAP,
        )
        .add(
            "地理坐标",
            time_price[price],
            type_=ChartType.EFFECT_SCATTER,blur_size = 8,color='yellow',
        )
        .set_series_opts(label_opts=opts.LabelOpts(is_show=True))
        .set_global_opts(title_opts=opts.TitleOpts(title="2000-2017年北京市各区房价(平米)中位数分布图"),
                         visualmap_opts=opts.VisualMapOpts(),
                         legend_opts = opts.LegendOpts(pos_right='right'))
        )
        tl.add(geo_, price)
    return tl

timeline_map().render_notebook()
# Out:
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/composite_charts/timeline.py:12: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '北京':'https://assets.pyecharts.org/assets/maps/beijing'
#         }
#     });
# </script>
#
#         <div id="9bfbc97cf65e4242b0735dd0f50859d8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '北京'], function(echarts) {
#                 var chart_9bfbc97cf65e4242b0735dd0f50859d8 = echarts.init(
#                     document.getElementById('9bfbc97cf65e4242b0735dd0f50859d8'), 'white', {renderer: 'canvas'});
#                 var option_9bfbc97cf65e4242b0735dd0f50859d8 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "heatmap",
#                 "name": "\u623f\u5c4b\u5747\u4ef7",
#                 "coordinateSystem": "geo",
#                 "data": [
#                     {
#                         "name": "\u5927\u5174",
#                         "value": [
#                             116.33,
#                             39.73,
#                             null
#                         ]
#                     },
#                     {
#                         "name": "\u623f\u5c71",
#                         "value": [
#                             116.13,
#                             39.75,
#                             null
#                         ]
#                     },
#                     {
#                         "name": "\u660c\u5e73",
#                         "value": [
#                             116.23,
#                             40.22,
#                             null
#                         ]
#                     },
#                     {
#                         "name": "\u671d\u9633",
#                         "value": [
#                             120.27,
#                             41.34,
#                             null
#                         ]
#                     },
#                     {
#                         "name": "\u6d77\u6dc0",
#                         "value": [
#                             116.3,
#                             39.95,
#                             null
#                         ]
#                     },
#                     {
#                         "name": "\u897f\u57ce",
#                         "value": [
#                             116.37,
#                             39.92,
#                             null
#                         ]
#                     }
#                 ],
#                 "pointSize": 20,
#                 "blurSize": 20,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "rippleEffect": {
#                     "show": true,
#                     "brushType": "stroke",
#                     "scale": 2.5,
#                     "period": 4
#                 }
#             },
#             {
#                 "type": "effectScatter",
#                 "name": "\u5730\u7406\u5750\u6807",
#                 "coordinateSystem": "geo",
#                 "showEffectOn": "render",
#                 "rippleEffect": {
#                     "show": true,
#                     "brushType": "stroke",
#                     "scale": 2.5,
#                     "period": 4
#                 },
#                 "symbolSize": 12,
#                 "data": [
#                     {
#                         "name": "\u5927\u5174",
#                         "value": [
#                             116.33,
#                             39.73,
#                             null
#                         ]
#                     },
#                     {
#                         "name": "\u623f\u5c71",
#                         "value": [
#                             116.13,
#                             39.75,
#                             null
#                         ]
#                     },
#                     {
#                         "name": "\u660c\u5e73",
#                         "value": [
#                             116.23,
#                             40.22,
#                             null
#                         ]
#                     },
#                     {
#                         "name": "\u671d\u9633",
#                         "value": [
#                             120.27,
#                             41.34,
#                             null
#                         ]
#                     },
#                     {
#                         "name": "\u6d77\u6dc0",
#                         "value": [
#                             116.3,
#                             39.95,
#                             null
#                         ]
#                     },
#                     {
#                         "name": "\u897f\u57ce",
#                         "value": [
#                             116.37,
#                             39.92,
#                             null
#                         ]
#                     }
#                 ],
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2000",
#                 "2001",
#                 "2002",
#                 "2003",
#                 "2004",
#                 "2005",
#                 "2006",
#                 "2007",
#                 "2008",
#                 "2009",
#                 "2010",
#                 "2011",
#                 "2012",
#                 "2013",
#                 "2014",
#                 "2015",
#                 "2016"
#             ]
#         },
#         "geo": {
#             "map": "\u5317\u4eac",
#             "roam": true,
#             "emphasis": {}
#         },
#         "visualMap": {
#             "show": true,
#             "type": "continuous",
#             "min": 0,
#             "max": 100,
#             "inRange": {
#                 "color": [
#                     "#50a3ba",
#                     "#eac763",
#                     "#d94e5d"
#                 ]
#             },
#             "calculable": true,
#             "inverse": false,
#             "splitNumber": 5,
#             "orient": "vertical",
#             "showLabel": true,
#             "itemWidth": 20,
#             "itemHeight": 140,
#             "borderWidth": 0
#         }
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u623f\u5c4b\u5747\u4ef7",
#                         "\u5730\u7406\u5750\u6807"
#                     ],
#                     "selected": {
#                         "\u623f\u5c4b\u5747\u4ef7": true,
#                         "\u5730\u7406\u5750\u6807": true
#                     },
#                     "show": true,
#                     "right": "right",
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "heatmap",
#                     "name": "\u623f\u5c4b\u5747\u4ef7",
#                     "coordinateSystem": "geo",
#                     "data": [
#                         {
#                             "name": "\u4e1c\u57ce",
#                             "value": [
#                                 116.42,
#                                 39.93,
#                                 54033.0
#                             ]
#                         },
#                         {
#                             "name": "\u4e30\u53f0",
#                             "value": [
#                                 116.28,
#                                 39.85,
#                                 33953.0
#                             ]
#                         },
#                         {
#                             "name": "\u5927\u5174",

# %%
d = {'s':1,'a':2}
for i in d:
    print(i)
    print(d[i])
# Out:
# s
# 1
# a
# 2

# %%
# bj_house.to_csv('bj_house.csv',encoding='utf-8')

# %%
# 自定义创建箱型图的函数
def create_box(data, x_name='', y_name='', title='', hue = '', order_=[], scatter_=True):
    plt.rcParams['font.sans-serif'] = ['SimHei']
    sns.boxplot(x=x_name, y=y_name, data=data,
                hue = hue,
                linewidth=2,  # 线宽
                width=0.8,  # 箱子之间的间隔比例
                fliersize=3,  # 异常点大小
                palette='hls',  # 设置调色板
                whis=1.5,  # 设置IQR
                notch=False,  # 设置是否以中值做凹槽
                order=order_)  # 筛选类别
    if scatter_ == True:
        sns.swarmplot(x=x_name, y=y_name, data=data, color='k', size=3, alpha=0.6)
    plt.legend(loc='upper left')
    plt.title(title)
    return

# %%
# 绘制各年份有无地铁平均房价分布图
create_box(bj_house,'period','price','The Boxplot of House Price from 2000 to 2016','subway',order_=['2000-2004','2005-2008','2009-2012','2013-2016'],scatter_=False)

# %%
bj_house['buildingStructure'].unique()
# Out:
# array(['钢混结构', '混和结构', '砖混结构', '未知结构', '钢结构', '砖木结构', '混合结构'],
#       dtype=object)

# %%
from matplotlib.font_manager import FontProperties

# 读取字体路径，设置字体为思源黑体
myfont=FontProperties(fname='/Users/Library/Fonts/SourceHanSansSC-Normal.otf')
sns.set(font=myfont.get_family())
sns.set_style("whitegrid",{"font.sans-serif":['Source Han Sans CN']})

作者：MilankakaZhang
链接：https://www.zhihu.com/question/48250674/answer/493471673
来源：知乎
著作权归作者所有。商业转载请联系作者获得授权，非商业转载请注明出处。

# %%
# 绘制建筑结构和房屋每平米价格分布图
create_box(bj_house,'buildingStructure','price','The Boxplot of House Price in deffierent period and building structure','period',order_=['钢混结构', '混和结构', '砖混结构', '未知结构', '钢结构', '砖木结构', '混合结构'],scatter_=False)
# Out:
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 38050 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 28151 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 32467 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26500 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 21644 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 30742 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26410 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 30693 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 21512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 38050 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 28151 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 32467 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26500 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 21644 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 30742 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26410 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 30693 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 21512 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 绘制建筑类型和房屋每平米价格分布图
create_box(bj_house, 'buildingType', 'price',
                      'The Boxplot of House Price in deffierent period and building type', 'period',
                      order_=['塔楼', '板楼', '板塔结合', '无类型', '平房'], scatter_=False)
# Out:
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 22612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 27004 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26495 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 32467 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 21512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26080 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 31867 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 22411 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 24179 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 25151 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 22612 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 27004 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26495 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 32467 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 21512 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26080 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 31867 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 22411 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 24179 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ashzerm/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 25151 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
bj_house['buildingType'].unique()
# Out:
# array(['塔楼', '板楼', '板塔结合', '无类型', '平房'], dtype=object)

# %%
# 绘制散点图加边缘分布图
def create_sca_join(data, x='', y=''):
    fig = sns.JointGrid(x=x, y=y, data=data)
    fig.plot_joint(plt.scatter, color='m', edgecolor='white')  # 设置框内图表scatter
    fig.ax_marg_x.hist(data[x], color="b", alpha=0.6)
    fig.ax_marg_y.hist(data[y], color='r', alpha=0.6, orientation="horizontal")
    return

# %%
def max_min_scale(data):
    return (data - min(data)) / (max(data) - min(data))

# %%
bj_house['sta_square'] = (bj_house['square'] - min(bj_house['square']))/(max(bj_house['square'])-min(bj_house['square']))
bj_house['sta_price'] = (bj_house['price'] - min(bj_house['price']))/(max(bj_house['price'])-min(bj_house['price']))
create_sca_join(bj_house,'sta_square','sta_price')

# %%
# 判断成交总价是否等于每平米价格x建筑面积 不等于
sum(bj_house['totalPrice']-bj_house['square']*bj_house['price'])
# Out:
# -1112787252351.671

# %%
# 但有极强的共线性，因此用这个指标进行预测是无意义的
bj_house['avg_price'] = bj_house['totalPrice']/bj_house['square']
create_sca_join(bj_house,'avg_price','price')

# %%
bj_house['avg_community'] = max_min_scale(bj_house['communityAverage'])
create_sca_join(bj_house,'avg_community','sta_price')

# %%
def get_year(date):
    return [i.split('/')[0] for i in date]

# %%
# 计算建筑使用年限
bj_house['trade_year'] = get_year(bj_house['tradeTime'])
bj_house['used_year'] = bj_house['trade_year'].map(lambda x:int(x))-bj_house['constructionTime'].map(lambda x:int(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-07ad56371035> in <module>
#       1 # 计算建筑使用年限
#       2 bj_house['trade_year'] = get_year(bj_house['tradeTime'])
# ----> 3 bj_house['used_year'] = bj_house['trade_year'].map(lambda x:int(x))-bj_house['constructionTime'].map(lambda x:int(x))
#
# ~/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# ~/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1143
#    1144         # mapper is a function
# -> 1145         new_values = map_f(values, mapper)
#    1146
#    1147         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-114-07ad56371035> in <lambda>(x)
#       1 # 计算建筑使用年限
#       2 bj_house['trade_year'] = get_year(bj_house['tradeTime'])
# ----> 3 bj_house['used_year'] = bj_house['trade_year'].map(lambda x:int(x))-bj_house['constructionTime'].map(lambda x:int(x))
#
# ValueError: invalid literal for int() with base 10: '未知'

# %%
bj_house['tradeTime'].unique()
# Out:
# array(['2016/8/9', '2016/7/28', '2016/12/11', ..., '2012/1/28',
#        '2011/1/30', '2009/1/11'], dtype=object)

# %%
bj_house['constructionTime'].unique()
# Out:
# array(['2005', '2004', '2008', '1960', '1997', '2009', '2006', '1991',
#        '2001', '1990', '2011', '2000', '1998', '2010', '1996', '1993',
#        '2002', '未知', '2012', '1989', '2003', '2007', '1994', '1984',
#        '1992', '2014', '1985', '2013', '1999', '1979', '1981', '1976',
#        '1982', '1975', '1983', '1986', '1995', '1965', '1988', '1987',
#        '2015', '1955', '1980', '1978', '1958', '1970', '1956', '1977',
#        '1964', '1963', '1967', '2016', '1974', '1973', '1959', '1954',
#        '1962', '1966', '1957', '1944', '1972', '1971', '1953', '1968',
#        '1961', '1950', '1952', '1933', '1969', '1', '0', '1906', '1934',
#        '1914'], dtype=object)

# %%
sum(bj_house['constructionTime']=='未知')
# Out:
# 19283
